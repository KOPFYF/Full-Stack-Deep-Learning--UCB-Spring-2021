# %%
# !nvidia-smi
# Out:
# Mon Aug  9 21:23:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# FSDL Spring 2021 Setup
# !git clone https://github.com/full-stack-deep-learning/fsdl-text-recognizer-2021-labs
# %cd fsdl-text-recognizer-2021-labs
# !pip3 install boltons wandb pytorch_lightning==1.1.4 pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 torchtext==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# %env PYTHONPATH=.:$PYTHONPATH
# Out:
# Cloning into 'fsdl-text-recognizer-2021-labs'...
# remote: Enumerating objects: 798, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 798 (delta 164), reused 147 (delta 143), pack-reused 568
# Receiving objects: 100% (798/798), 18.88 MiB | 21.53 MiB/s, done.
# Resolving deltas: 100% (402/402), done.
# /content/fsdl-text-recognizer-2021-labs
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 193 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 13.1 MB/s
# ...
#      |████████████████████████████████| 684 kB 42.2 MB/s
# ...

# %%
# %cd lab2/
# Out:
# /content/fsdl-text-recognizer-2021-labs/lab2

# %%
# %pwd
# Out:
# '/content/fsdl-text-recognizer-2021-labs/lab2'

# %%
# Intentional overfitting --overfit_batches=0.01
# only use this fraction of data to train, and test on the same data
# !python training/run_experiment.py --max_epochs=30 --gpus=-1 --num_workers=20 --model_class=CNN --data_class=EMNIST --overfit_batches=0.01
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-08-09 21:31:35.410994: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
#    | Name             | Type      | Params
# ------------------------------------------------
# 0  | model            | CNN       | 1.7 M
# 1  | model.conv1      | ConvBlock | 640
# 2  | model.conv1.conv | Conv2d    | 640
# 3  | model.conv1.relu | ReLU      | 0
# 4  | model.conv2      | ConvBlock | 36.9 K
# 5  | model.conv2.conv | Conv2d    | 36.9 K
# 6  | model.conv2.relu | ReLU      | 0
# 7  | model.dropout    | Dropout   | 0
# ...

# %%
# test homework with more layers added, like a ResNet block
# !python training/run_experiment.py --max_epochs=10 --gpus=-1 --num_workers=20 --model_class=CNN --data_class=EMNIST --overfit_batches=0.01
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-08-09 21:55:14.798858: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
#    | Name              | Type            | Params
# -------------------------------------------------------
# 0  | model             | CNN             | 1.8 M
# 1  | model.conv1       | ConvBlock_extra | 75.5 K
# 2  | model.conv1.conv1 | Conv2d          | 1.3 K
# 3  | model.conv1.bn1   | BatchNorm2d     | 256
# 4  | model.conv1.relu1 | ReLU            | 0
# 5  | model.conv1.conv2 | Conv2d          | 73.8 K
# ...

# %% [markdown]
# # New Section
